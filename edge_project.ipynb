# %% [markdown]
# <a href="https://colab.research.google.com/github/rashed-30/edge_project/blob/main/edge_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

drive.mount('/content/drive')
path = '/content/drive/My Drive/Edge/student_data.csv'
df = pd.read_csv(path)

students_low_attendance_or_missing = df[(df['Attendence(%)'] < 75) | (df['Assignment completion'] == 'No')]

print("Students with attendence less than 75%:")
print(students_low_attendance_or_missing)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')
path = "/content/drive/My Drive/Edge/student_data.csv"
df = pd.read_csv(path)

# Step 2: Calculate Average Score
average_scores = {
    'Bangla': df['Bangla'].mean(),
    'Math': df['Math'].mean(),
    'English': df['English '].mean()
}

plt.figure(figsize=(8, 6))
plt.bar(average_scores.keys(), average_scores.values(), color=['blue', 'green','red'])

# Step 4: Customize the Chart
plt.title('Average Score', fontsize=16)
plt.xlabel('Metric', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.ylim(0, 100)  # Assuming scores are out of 100

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

# Step 1: Mount Google Drive and Load Data
drive.mount('/content/drive')
path = "/content/drive/My Drive/Edge/student_data.csv"
df = pd.read_csv(path)
average_scores = {
    'Bangla': df['Bangla'].mean(),
    'Math': df['Math'].mean(),
    'English': df['English '].mean()
}

plt.figure(figsize=(5,5))
plt.pie(
    average_scores.values(),
    labels=average_scores.keys(),
    autopct='%d%%',
    startangle=140,
    colors=['yellow','green','red'],
)
plt.title('Average Scores by Subject', fontsize=16)
plt.axis('equal')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

# Step 1: Mount Google Drive and Load Data
drive.mount('/content/drive')
path = "/content/drive/My Drive/Edge/student_data.csv"
df = pd.read_csv(path)
def categorize_attendance(value):
    if value < 50:
        return "<50%"
    elif 50 <= value <= 75:
        return "50-75%"
    else:
        return ">75%"

df["Attendance Category"] = df["Attendence(%)"].apply(categorize_attendance)

# Count categories
category_counts = df["Attendance Category"].value_counts()

# Plot pie chart
plt.figure(figsize=(8, 6))
plt.pie(
    category_counts,
    labels=category_counts.index,
    autopct="%1.1f%%",
    startangle=90,
    colors=["#66c2a5", "#fc8d62", "#8da0cb"],
    wedgeprops={"edgecolor": "black", "linewidth": 1}
)
plt.title("Attendance Percentage Categories", fontsize=14)
plt.show()


selected_student = "Sakil"  # Replace with the desired student's name
subjects = ["Bangla", "English ", "Math"]
performance = df[df["Name"] == selected_student][subjects].values.flatten()

plt.figure(figsize=(10, 6))
plt.plot(subjects, performance, marker="o", linestyle="-", color="g")
plt.xlabel("Subjects", fontsize=12)
plt.ylabel("Marks", fontsize=12)
plt.title(f"Performance Trends for {selected_student}", fontsize=14)
plt.ylim(0, 100)
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

# Step 1: Mount Google Drive and Load Data
drive.mount('/content/drive')
path = "/content/drive/My Drive/Edge/student_data.csv"
df = pd.read_csv(path)

# Calculate aggregate scores for each student
df["Aggregate Score"] = df[["Bangla", "English ", "Math"]].sum(axis=1)

# Display aggregate scores
print("Aggregate Scores for Each Student:")
print(df[["Name", "Aggregate Score"]])

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive


# Mount the drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/Edge/student_data.csv"
df = pd.read_csv(path)

# Function to determine grade
def determine_grade(Bangla):
    if 80 <= Bangla <= 100:
        return "A+"
    elif 70 <= Bangla <= 79:
        return "A"
    elif 60<= Bangla<= 69:
        return "A-"
    elif 50 <= Bangla <=59:
        return "B"
    elif 40 <= Bangla <= 49:
        return "C"
    else:
        return "Fail"
def determine_grade(English):
    if 80 <= English <= 100:
        return "A+"
    elif 70 <= English <= 79:
        return "A"
    elif 60<= English<= 69:
        return "A-"
    elif 50 <= English <=59:
        return "B"
    elif 40 <= English <= 49:
        return "C"
    else:
        return "Fail"
def determine_grade(Math):
    if 80 <= Math <= 100:
        return "A+"
    elif 70 <= Math <= 79:
        return "A"
    elif 60<= Math<= 69:
        return "A-"
    elif 50 <= Math <=59:
        return "B"
    elif 40 <= Math <= 49:
        return "C"
    else:
        return "Fail"


df['Grade'] = df['Bangla'].apply(determine_grade)
df['Grade1'] = df['English '].apply(determine_grade)
df['Grade2'] = df['Math'].apply(determine_grade)


df.to_csv("/content/drive/MyDrive/student_detail/graded_data.csv", index=False)


print(df[["Name", "Bangla","Grade","English ","Grade1","Math","Grade2"]])

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')
path = "/content/drive/My Drive/Edge/student_data.csv"
df = pd.read_csv(path)

df["score"] = df[["Bangla", "English ", "Math"]].sum(axis=1)

def performance(score):
    if 240 <= score <= 300:
        return "Excellent"
    elif 210 <= score <= 239:
        return "Very Good"
    elif 180<= score <= 209:
        return "Good"
    elif 150<= score <= 179:
        return "Need Improvement"
    else:
        return "Not satisfied"

df['Performance'] = df['score'].apply(performance)

output_path = "/content/drive/My Drive/Edge/student_data.csv"
df.to_csv(output_path, index=False)

print(df[["Name", "score", "Performance"]])

# %%
import csv

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv
from google.colab import drive
drive.mount('/content/drive')

# File to store student data
file_path = '/content/drive/My Drive/Edge/student_data.csv'

# Ensure the CSV file has a header if it doesn't exist
try:
    with open(file_path, mode="x", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["Student Name", "Student ID", "Subject", "Score", "Attendance Percentage", "Assignment Completion"])
except FileExistsError:
    pass  # File already exists, no need to create a new one

# Function to add a new entry
def add_entry():
    with open(file_path, mode="a", newline="") as file:
        writer = csv.writer(file)
        print("\nEnter student data (leave 'Student Name' blank to stop):")
        while True:
            student_name = input("Student Name: ")
            if not student_name:  # Stop when no name is entered
                break
            student_id = input("Student ID: ")
            subject = input("Subject: ")
            score = input("Score: ")
            attendance_percentage = input("Attendance Percentage: ")
            assignment_completion = input("Assignment Completion (Yes/No): ")
            writer.writerow([student_name, student_id, subject, score, attendance_percentage, assignment_completion])
        print("Entries added successfully!")

# Function to search for a student
def search_student():
    search_term = input("\nEnter Student Name or ID to search: ").strip()
    with open(file_path, mode="r") as file:
        reader = csv.reader(file)
        header = next(reader)  # Skip the header row
        found = False
        print("\nSearch Results:")
        for row in reader:
            if search_term in row:  # Search by name or ID
                print(dict(zip(header, row)))  # Print matching row as a dictionary
                found = True
        if not found:
            print("No student found with the given name or ID.")

# Function to update a student's score or attendance
def update_score_attendance():
    student_id = input("\nEnter Student ID to update: ").strip()
    updated_rows = []
    found = False

    # Read and update data
    with open(file_path, mode="r") as file:
        reader = csv.reader(file)
        header = next(reader)
        updated_rows.append(header)  # Keep the header

        for row in reader:
            if row[1] == student_id:  # Check Student ID
                print(f"\nCurrent Record: {dict(zip(header, row))}")
                new_score = input("Enter New Score (leave blank to keep current): ").strip()
                new_attendance = input("Enter New Attendance Percentage (leave blank to keep current): ").strip()
                new_assignment = input("Enter Assignment Status (leave blank to keep current): ").strip()
                if new_score:
                    row[3] = new_score
                if new_attendance:
                    row[4] = new_attendance
                if new_assignment:
                    row[5] = new_assignment
                found = True
            updated_rows.append(row)

    if found:
        # Write updated data back to file
        with open(file_path, mode="w", newline="") as file:
            writer = csv.writer(file)
            writer.writerows(updated_rows)
        print("Student record updated successfully!")
    else:
        print("No student found with the given ID.")
def ind_sum():
  import pandas as pd
  df = pd.read_csv(file_path)
  print(df)
  df['Average Score'] = df[['Bangla','English ', 'Math']].mean(axis=1)
  df['Maximum'] = df[['Bangla','English ','Math']].max(axis=1)
  df['Minimum'] = df[['Bangla','English ','Math']].min(axis=1)
  print(df[['Name', 'ID', 'Average Score', 'Maximum', 'Minimum']])


# Main menu
while True:
    print("\nMenu:")
    print("1. Add new entry")
    print("2. Search for a student")
    print("3. Update student's score or attendance")
    print("4. Individual score summary")
    print("5. Exit")

    choice = input("Choose an option from 1 to 5: ").strip()

    if choice == "1":
        add_entry()
    elif choice == "2":
        search_student()
    elif choice == "3":
        update_score_attendance()
    elif choice == "4":
        ind_sum()
    elif choice == "5":
        print("Exiting the program...")
        break
    else:
        print("Invalid choice, please select a number from 1 to 4.")
# Out:
# Menu:
# 1. Add new entry
# 2. Search for a student
# 3. Update student's score or attendance
# 4. Exit
# Choose an option from 1 to 4: 2
#
# Enter Student Name or ID to search: Rashed
#
# Search Results:
# {'Student Name': 'Rashed', 'Student ID': 'ST001', 'Subject': 'Phy', 'Score': '88', 'Attendance Percentage': '100', 'Assignment Completion': 'Yes'}
# {'Student Name': 'Rashed', 'Student ID': 'ST001', 'Subject': 'Bio', 'Score': '86', 'Attendance Percentage': '100', 'Assignment Completion': 'Yes'}
# {'Student Name': 'Rashed', 'Student ID': 'Chem', 'Subject': 'Chem', 'Score': '3', 'Attendance Percentage': '32', 'Assignment Completion': '2'}
# {'Student Name': 'Rashed', 'Student ID': 'ST001', 'Subject': 'Chem', 'Score': '83', 'Attendance Percentage': '100', 'Assignment Completion': 'Yes'}
#
# Menu:
# 1. Add new entry
# 2. Search for a student
# 3. Update student's score or attendance
# 4. Exit
# Choose an option from 1 to 4: 3
#
# Enter Student ID to update: ST001
#
# ...
